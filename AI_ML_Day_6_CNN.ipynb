# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt

# %%
mist = keras.datasets.mnist.load_data()

# %%
(x_train, y_train), (x_test, y_test) = mist
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
model=keras.Sequential([
    keras.Input(shape=(28,28)), # Define input shape explicitly
    keras.layers.Flatten(),
    keras.layers.Dense(128, activation='relu'),
    keras.layers.Dropout(0.2),
    keras.layers.Dense(10, activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(x_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9147 - loss: 0.2950
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9567 - loss: 0.1440
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9664 - loss: 0.1106
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9726 - loss: 0.0905
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9766 - loss: 0.0752

# %%
test_loss, test_acc = model.evaluate(x_test,  y_test, verbose=2)
print(f'\nTest accuracy: {test_acc:.4f}')
# Out:
# 313/313 - 2s - 6ms/step - accuracy: 0.9772 - loss: 0.0785
#
# Test accuracy: 0.9772

# %%
predictions=model.predict(x_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
import numpy as np
plt.imshow(x_test[0], cmap='gray')
plt. title(f'Predicted: {np.argmax(predictions[0])}')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

predictions = model.predict(x_test)

plt.figure(figsize=(12, 6))

for i in range(10):
    plt.subplot(2, 5, i + 1)
    plt.imshow(x_test[i], cmap='gray')

    predicted_label = np.argmax(predictions[i])
    true_label = y_test[i]

    plt.title(f"P:{predicted_label}\nT:{true_label}")
    plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
